# %%
import pandas as pd
import anndata
import evolocity as evo
import scanpy as sc
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # All OVA sequences (full length VDJ)

# %% [markdown]
# #### ESM

# %%
adata = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/OVA_V7/evo-velocity/adata_AllSamples_full_VDJ_esm.h5ad")
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 6002 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'clonotype', 'v_gene_family', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata, color="sample", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata, color="v_gene_family", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata, color="isotype", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# #### ProtBERT

# %%
adata_protbert = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/OVA_V7/evo-velocity/adata_AllSamples_full_VDJ_protbert.h5ad")
print(adata_protbert)
# Out:
# AnnData object with n_obs × n_vars = 6002 × 1024
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'clonotype', 'v_gene_family', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_protbert, color="sample", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata_protbert, color="v_gene_family", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata_protbert, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# #### Ablang

# %%
adata_ablang = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/OVA_V7/evo-velocity/adata_AllSamples_full_VDJ_ablang.h5ad")
print(adata_ablang)
# Out:
# AnnData object with n_obs × n_vars = 6030 × 768
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'clonotype', 'v_gene_family', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_ablang, color="sample", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata_ablang, color="v_gene_family", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata_ablang, color="isotype", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata_ablang, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# ## Sapiens

# %%
adata_sapiens = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/OVA_V7/evo-velocity/adata_AllSamples_full_VDJ_sapiens.h5ad")
print(adata_sapiens)
# Out:
# AnnData object with n_obs × n_vars = 6002 × 128
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'clonotype', 'v_gene_family', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_sapiens, color="sample", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata_sapiens, color="v_gene_family", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata_sapiens, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# # V-gene subfamilies

# %% [markdown]
# ## IGHV3-1

# %%
adata_31 = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/OVA_V7/evo-velocity/adata_IGHV3-1_IncludingGermline_v_gene_only_esm.h5ad")
print(adata_31)
# Out:
# AnnData object with n_obs × n_vars = 126 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'v_gene', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_31, color="isotype", legend_loc="right margin", title="IGHV3-1")

# %%
ax = evo.pl.velocity_embedding_stream(adata_31, color="SHM_count", legend_loc="right margin", size = 3000, alpha = 0.7)

# %% [markdown]
# ## IGHV5-6

# %%
adata_56 = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/OVA_V7/evo-velocity/adata_IGHV5-6_IncludingGermline_v_gene_only_esm.h5ad")
print(adata_56)
# Out:
# AnnData object with n_obs × n_vars = 153 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'v_gene', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_56, color="isotype", legend_loc="right margin", title="IGHV5-6")

# %%
ax = evo.pl.velocity_embedding_stream(adata_56, color="SHM_count", legend_loc="right margin", size = 3000, alpha = 0.7)

# %% [markdown]
# ## IGHV9-3

# %%
adata_93 = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/OVA_V7/evo-velocity/adata_IGHV9-3_IncludingGermline_v_gene_only_esm.h5ad")
print(adata_93)
# Out:
# AnnData object with n_obs × n_vars = 172 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'v_gene', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_93, color="isotype", legend_loc="right margin", title="IGHV9-3")

# %%
ax = evo.pl.velocity_embedding_stream(adata_93, color="SHM_count", legend_loc="right margin", size = 3000, alpha = 0.7)
