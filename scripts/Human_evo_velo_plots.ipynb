# %%
import pandas as pd
import anndata
import evolocity as evo
import scanpy as sc
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # All human sequences (full length VDJ)

# %% [markdown]
# ## ESM-1b

# %% [markdown]
# #### Import AnnData object

# %%
adata = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/adata_AllHumanSamples_full_VDJ_esm.h5ad")
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 17624 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'clonotype', 'v_gene_family', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata, color="sample", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata, color="v_gene_family", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# ## Protbert

# %%
adata_pb = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/adata_AllHumanSamples_full_VDJ_protbert.h5ad")
print(adata_pb)
# Out:
# AnnData object with n_obs × n_vars = 17624 × 1024
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'clonotype', 'v_gene_family', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_pb, color="sample", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata_pb, color="v_gene_family", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata_pb, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# ## Ablang

# %%
adata_al = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/adata_AllHumanSamples_full_VDJ_ablang.h5ad")
print(adata_al)
# Out:
# AnnData object with n_obs × n_vars = 18072 × 768
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'clonotype', 'v_gene_family', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_al, color="sample", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata_al, color="v_gene_family", legend_loc="right margin")

# %%
ax = evo.pl.velocity_embedding_stream(adata_al, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# ## Sapiens

# %% [markdown]
# # V-gene subfamilies

# %% [markdown]
# ## IGHV1-69D

# %%
adata_69 = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/adata_IGHV1-69D_IncludingGermline_v_gene_only_esm.h5ad")
print(adata_69)
# Out:
# AnnData object with n_obs × n_vars = 490 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'v_gene', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_69, color="isotype", legend_loc="right margin", size=50, alpha=1, title="IGHV1-69D")

# %%
ax = evo.pl.velocity_embedding_stream(adata_69, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# ## IGHV3-23

# %%
adata_323 = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/adata_IGHV3-23_IncludingGermline_v_gene_only_esm.h5ad")
print(adata_323)
# Out:
# AnnData object with n_obs × n_vars = 950 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'v_gene', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_323, color="isotype", legend_loc="right margin", title="IGHV3-23")

# %%
ax = evo.pl.velocity_embedding_stream(adata_323, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# ## IGHV3-33

# %%
adata_333 = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/adata_IGHV3-33_IncludingGermline_v_gene_only_esm.h5ad")
print(adata_333)
# Out:
# AnnData object with n_obs × n_vars = 944 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'v_gene', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_333, color="isotype", legend_loc="right margin", title="IGHV3-33", size=100, alpha=1)

# %%
ax = evo.pl.velocity_embedding_stream(adata_333, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# ## IGHV4-59

# %%
adata_459 = sc.read_h5ad("/Users/dginneke/OneDrive - UMC Utrecht/Documenten/Project_EvoLikelihood/PLM-likelihoods/data/adata_IGHV4-59_IncludingGermline_v_gene_only_esm.h5ad")
print(adata_459)
# Out:
# AnnData object with n_obs × n_vars = 730 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'v_gene', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_459, color="isotype", legend_loc="right margin", title="IGHV4-59", alpha=0.1, size=500, 
                                      palette=["pink","pink","pink","pink","black","pink"])

# %%
ax = evo.pl.velocity_embedding_stream(adata_459, color="SHM_count", legend_loc="right margin", title="IGHV4-59", alpha=1, size=60)
